# %%
#определим число уникальных категорий в каждом столбце нашей таблицы melb_df

import pandas as pd
melb_df = pd.read_csv('data/melb_data_ps.csv', sep=',')

#Создаём пустой список, в который будем добавлять кортежи: имя столбца, количество уникальных значений в нём и тип столбца.
unique_list = []
for col in melb_df.columns:
    # В цикле перебираем имена столбцов, которые получаем с помощью атрибута columns. 
    # В переменной col на каждой итерации находятся имена столбцов —
    # обращаемся к ним в цикле и извлекаем число уникальных элементов с помощью метода nunique(), 
    # а также тип столбца с помощью атрибута dtypes. 
    # Результат заносим в кортеж и добавляем его в список.
    item = (col, melb_df[col].nunique(), melb_df[col].dtype)
    unique_list.append(item)
# Из списка с кортежами (имя столбца, количество уникальных значений в нём, тип столбца) создаём DataFrame,
# даём названия его столбцам: Column_Name, Num_unique и Type.
unique_counts = pd.DataFrame(unique_list, 
                             columns=['Column_Name','Num_Unique', 'Type']).sort_values(by = 'Num_Unique', ignore_index=True)
#Сортируем таблицу по столбцу Num_unique в порядке возрастания количества уникальных элементов с помощью метода sort_values()

display(unique_counts)
# Out:
#       Column_Name  Num_Unique     Type
# 0            Type           3   object
# 1          Method           5   object
# 2      Regionname           8   object
# 3           Rooms           9    int64
# 4        Bathroom           9    int64
# 5             Car          11    int64
# 6         Bedroom          12    int64
# 7     CouncilArea          33   object
# 8            Date          58   object
# 9       YearBuilt         144    int64
# 10       Postcode         198    int64
# 11       Distance         202  float64
# 12        SellerG         268   object
# 13  Propertycount         311    int64
# 14         Suburb         314   object
# 15   BuildingArea         602  float64
# 16       Landsize        1448  float64
# 17          Price        2204  float64
# 18      Lattitude        6503  float64
# 19     Longtitude        7063  float64
# 20    Coordinates       13097   object
# 21        Address       13378   object
# 22          index       13580    int64

# %%
melb_df['Suburb'] = melb_df['Suburb'].astype('category')
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  category
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...
